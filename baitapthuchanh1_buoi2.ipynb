# %% [markdown]
# <a href="https://colab.research.google.com/github/doanthuchuyen/thuchuyen07.github.io/blob/gh-pages/baitapthuchanh1_buoi2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BÀI TẬP MẪU

# %%
# bai 1
print('Whoever is happy will make others happy too')
print('--Anne Frank')
# Out:
# Whoever is happy will make others happy too
# --Anne Frank

# %%
# bai 2
a = int(input("Moi ban nhap so a: "))
b = int(input("Moi ban nhap so b: "))

kqCong = a + b
kqTru = a - b
kqNhan = a * b
kqChiaNguyen = a // b
kqDu= a % b
kqChiaThuc = a / b

print("Cac ket qua tinh toan: ")
print("%-5d + %5d = %5d"%(a, b, kqCong))
print("%-5d - %5d = %5d"%(a, b, kqTru))
print("%-5d * %5d = %5d"%(a, b, kqNhan))
print("%-5d / %5d = %5d"%(a, b, kqChiaNguyen))
print("%-5d / %5d = %5d"%(a, b, kqDu))
print("%-5d / %5d = %5.2f"%(a, b, kqChiaThuc))
# Out:
# Moi ban nhap so a: 7
# Moi ban nhap so b: 5
# Cac ket qua tinh toan:
# 7     +     5 =    12
# 7     -     5 =     2
# 7     *     5 =    35
# 7     /     5 =     1
# 7     /     5 =     2
# 7     /     5 =  1.40

# %%
# bai 3
a=float(input('moi ban nhap so a: '))
b=float(input('moi ban nhap so b: '))
lanhohon=(a<b)
lanhohonbang=(a<=b)
lalonhon=(a>b)
lalonhonbang=(a>=b)
labang=(a==b)
lakhacnhau=(a!=b)
print('ket qua so sanh hai so thuc %.2f va %.2f:'%(a, b))
print('%-8.2f<%8.2f: %8s'%(a, b, lanhohon))
print('%-8.2f<=%8.2f: %8s'%(a, b, lanhohonbang))
print('%-8.2f>%8.2f: %8s'%(a, b, lalonhon))
print('%-8.2f>=%8.2f: %8s'%(a, b, lalonhonbang))
print('%-8.2f==%8.2f: %8s'%(a, b, labang))
print('%-8.2f!=%8.2f: %8s'%(a, b, lakhacnhau))
# Out:
# moi ban nhap so a: 3
# moi ban nhap so b: 6
# ket qua so sanh hai so thuc 3.00 va 6.00:
# 3.00    <    6.00:     True
# 3.00    <=    6.00:     True
# 3.00    >    6.00:    False
# 3.00    >=    6.00:    False
# 3.00    ==    6.00:    False
# 3.00    !=    6.00:     True

# %%
# bai 4
import math
x=float(input('moi ban nhap gia tri cua bien so x: '))
fx=x+math.pow(x, 5)/(1*2*3*4*5)+\
    math.sqrt(abs(x))/math.pow(x, 3.0/2)
print('gia tri cua ham so f(%.2f)=%.2f.'%(x, fx))
# Out:
# moi ban nhap gia tri cua bien so x: 9
# gia tri cua ham so f(9.00)=501.19.

# %%
# bai 5
x=int(input('nhap so nguyen n cos 4 chu so: '))
a=x//100
b=(x//100)%10
c=(x//10)%10
d=x%10
tong=a+b+c+d
print('tong cac chu so la: ', tong)
# Out:
# nhap so nguyen n cos 4 chu so: 2345
# tong cac chu so la:  35

# %% [markdown]
# BÀI TẬP THỰC HÀNH

# %%
# bai 1
print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
print('~~ Truong: Dai Hoc UEH     ~~')
print('~~ Khoa: Kinh Te           ~~')
print('~~ Ho ten: Doan Thuc Huyen ~~')
print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~~ Truong: Dai Hoc UEH     ~~
# ~~ Khoa: Kinh Te           ~~
# ~~ Ho ten: Doan Thuc Huyen ~~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
# bai 2
R=float(input('ban kinh R: '))
S = 3.14 * R * R
P = 2 * 3.14 * R

print("dien tich S la: {:.1f}".format(S))
print('chu vi P la: {:.1f}'.format(P))
# Out:
# ban kinh R: 6
# dien tich S la: 113.0
# chu vi P la: 37.7

# %%
# bai 3
a=int(input('nhap so gio: '))
b=int(input('nhap so phut: '))
c=int(input('nhap so giay: '))
tonggiay=a*3600+b*60+c
print('tong so giay = ', tonggiay)
# Out:
# nhap so gio: 3
# nhap so phut: 7
# nhap so giay: 40
# tong so giay =  11260

# %%
# bai 4
x=int(input('nhap tong so giay: '))
gio=x//3600
phut=(x%3600)//60
giay=x%60
print(f'{x} giay co dang {gio}:{phut}:{giay}')
# Out:
# nhap tong so giay: 4592
# 4592 giay co dang 1:16:32

# %%
# bai 5
import math
a=float(input('nhap do dai canh a: '))
b=float(input('nhap do dai canh b: '))
c=float(input('nhap do dai canh c: '))
p=(a+b+c)/2
s=math.sqrt(p*(p-a)*(p-b)*(p-c))
print(f'dien tich tam giac s = {s:.2f}')
# Out:
# nhap do dai canh a: 3
# nhap do dai canh b: 4
# nhap do dai canh c: 5
# dien tich tam giac s = 6.00

# %%
# bai 6
a=float(input('nhap so thuc a: '))
b=int(input('nhap so mu n: '))
ketqua=a**b
print(f'ket qua {a}^{b} = {ketqua}')
# Out:
# nhap so thuc a: 4
# nhap so mu n: 3
# ket qua 4.0^3 = 64.0

# %%
# bai 7
x=int(input('nhap so nguyen x: '))
y=int(str(x)[::-1])
print(f'so dao cua {x} la: {y}')
# Out:
# nhap so nguyen x: 43725
# so dao cua 43725 la: 52734

# %%
# bai 8
import math
degree=float(input('nhap goc (do): '))
radian=degree*math.pi/180
print(f'{degree} do = {radian:.4f} radian')
# Out:
# nhap goc (do): 56
# 56.0 do = 0.9774 radian

# %%
# bai 9
import math
x=float(input('so thuc x: '))
y1=4*(x**2+10*x*math.sqrt(x)+3*x+1)
y2=(math.sin(math.pi*x**2)+math.sqrt(x**2+1))/(math.exp(2*x)+math.cos((math.pi/4)*x))
print(f'y1={y1:.2f}')
print(f'y2={y2:.2f}')
# Out:
# so thuc x: 4
# y1=436.00
# y2=0.00

# %%
# bai 10
import math
x1=float(input('nhap x1: '))
x2=float(input('nhap x2: '))
y1=float(input('nhap y1: '))
y2=float(input('nhap y2: '))
d=math.sqrt((x2-x1)**2+(y2-y1)**2)
print(f'khoang cach giua A({x1}, {y1}) va B({x2}, {y2}) la: {d:5.2f}')
# Out:
# nhap x1: 4
# nhap x2: 6
# nhap y1: 3
# nhap y2: 9
# khoang cach giua A(4.0, 3.0) va B(6.0, 9.0) la:  6.32

# %% [markdown]
# BÀI TẬP TRÊN LỚP

# %%
# bai 1
a=int(input())
b=int(input())
c=int(input())
def max_fn(a, b):
  return a if a>b else b
  pass
vmax=max_fn(a, b)
vmax=max_fn(vmax, c)
print('max(%d, %d, %d) = %d'%(a, b, c, vmax))
# Out:
# 4
# 3
# 6
# max(4, 3, 6) = 6

# %%
# bai 2
a=int(input())
b=int(input())
c=int(input())
ket_qua = sorted([a, b, c])
print('ba so theo thu tu tang dan: ', ket_qua)
# Out:
# 6
# 3
# 8
# ba so theo thu tu tang dan:  [3, 6, 8]

# %%
# bai 3
a=float(input())
b=int(input())
def solv1deg(a, b):
  '''
  solve equation ax+b=0
  '''
  nsol, x= None, None
  if a ==0:
    if b==0:
      nsol=-1
    else:
      nsol=0
  else:
    nsol=1
    x=-b/a
  return nsol, x
  pass
nsol, x = solv1deg(a, b)
if nsol == -1:
  print('%.2fx+%.2f=0:ulimited solutions'%(a, b))
elif nsol==0:
  print('%.2fx+%.2f=0: no solution'%(a, b))
else:
  print('%.2fx+%.2f=0:x = %.2f'%(a, b, x))
# Out:
# 6
# 5
# 6.00x+5.00=0:x = -0.83

# %%
# bai 4
y=int(input('so nam n: '))
def isleap(y):
  ans=False
  if y%400==0 or (y%4==0 and y%100 !=0):
    ans = True
  return ans
  pass
def daysyear(y):
  ans=365
  if isleap(y):
    ans=366
  return ans
  pass
ans=daysyear(y)
print('%d'%(ans))
# Out:
# so nam n: 2030
# 365

# %%
# bai 5
a= float(input(''))
b=float(input(''))
phepcong=a+b
pheptru=a-b
phepnhan=a*b
print('ket qua phep cong: ', phepcong)
print('ket qua phep tru: ', pheptru)
print('ket qua phep nhan: ', phepnhan)
# Out:
# 9
# 7
# ket qua phep cong:  16.0
# ket qua phep tru:  2.0
# ket qua phep nhan:  63.0

# %%
# bai 6
chisocu=int(input('nhap chi so cu: '))
chisomoi=int(input('nhap chi so moi: '))
kWh=chisomoi-chisocu
if kWh<=100:
  tien=kWh*1242
elif kWh<=150:
  tien=100*1242+(kWh-100)*1304
elif kWh<=200:
  tien=100*1242+50*1304+(kWh-150)*1651
elif kWh<=300:
  tien=100*1242+50*1304+50*1651+(kWh-200)*1788
elif kWh<=400:
  tien=100*1242+50*1304+50*1651+100*1788+(kWh-300)*1912
else:
  tien=(100*1242+50*1304+50*1651+100*1788+100*1912+(kWh-400)*1962)
tienvat=tien*0.10
tongtien=tien+tienvat
print(f'so dien tieu thu la: {kWh} kWh')
print(f'tien dien (chua VAT) la: {tien:,} d')
print(f'thue VAT (10%) la: {tienvat:,.0f} d')
print(f'tong cong phai tra: {tongtien:,.0f} d')
# Out:
# nhap chi so cu: 4
# nhap chi so moi: 596
# so dien tieu thu la: 592 kWh
# tien dien (chua VAT) la: 1,018,654 d
# thue VAT (10%) la: 101,865 d
# tong cong phai tra: 1,120,519 d

# %%
# bai 7
def namnhuan(y):
  return(y%400==0)or(y%4==0 and y%100!=0)
def songaytrongnam(m, y):
  if m in[1, 3, 5, 7, 8, 10, 12]:
    return 31
  elif m in[4, 6, 9, 11]:
    return 30
  elif m==2:
    return 29 if namnhuan(y) else 28
def ngaytruoc(d, m, y):
  if d==1 and m==1:
    return 31, 12, y-1
  elif d==1:
    m_moi=m-1
    d_moi=songaytrongthangmoi(m_moi, y)
    return d_moi, m_moi, y
  else:
    return d-1, m, y
d=int(input('nhap ngay: '))
m=int(input('nhap thang:'))
y=int(input('nhap nam: '))
dpre, mpre, ypre=ngaytruoc(d, m, y)
print(f'ngay truoc do cua ngay {d}/{m}/{y} la: {dpre}/{mpre}/{ypre}')
# Out:
# nhap ngay: 31
# nhap thang:5
# nhap nam: 2005
# ngay truoc do cua ngay 31/5/2005 la: 30/5/2005

# %%
# bai 8
a=float(input('nhap canh a: '))
b=float(input('nhap canh b: '))
c=float(input('nhap canh c: '))
if a+b>c and a+c>b and ab+c>a:
  print('Ba canh a, b, c tao thanh mot tam giac.')
else:
  print('Ba canh a, b , c khong tao thanh mot tam giac.')
# Out:
# nhap canh a: 5
# nhap canh b: 2
# nhap canh c: 7
# Ba canh a, b , c khong tao thanh mot tam giac.

# %% [markdown]
# BÀI TẬP THÊM

# %%
# bai 1
a=float(input('a: '))
b=float(input('b: '))
c=float(input('c: '))
d=float(input('d: '))
e=float(input('e: '))
maxvalue=max(a, b, c, d, e)
minvalue=min(a, b, c, d, e)
print('gia tri lon nhat la: ', maxvalue)
print('gia tri nho nhat la: ', minvalue)
# Out:
# a: 45
# b: 64
# c: 39
# d: 2
# e: 7
# gia tri lon nhat la:  64.0
# gia tri nho nhat la:  2.0

# %%
# bai 2
import math
a=float(input('a: '))
b=float(input('b: '))
c=float(input('c: '))
if a==0:
  if b==0:
    if c==0:
      print('phuong trinh co vo so nghiem.')
    else:
      print('phuong trinh vo nghiem.')
  else:
    x=-c/b
    print('phuong trinh co mot nghiem duy nhat: x = ', x)
else:
  delta=b**2-4*a*c
  if delta <0:
    print('phuong trinh vo nghiem')
  elif delta ==0:
    x=-b/(2*a)
    print('phuong trinh co nghiem kep: x = ', x)
  else:
    x1=(-b+math.sqrt(delta))/(2*a)
    x2=(-b-math.sqrt(delta))/(2*a)
    print('phuong trinh co hai nghiem phan biet: ')
    print('x1 = ', x1)
    print('x2 = ', x2)
# Out:
# a: 4
# b: 3
# c: 7
# phuong trinh vo nghiem

# %%
# bai 3
month=int(input('nhap thang: '))
year=int(input('nhap nam: '))
if month in [1, 3, 5, 7, 8, 10, 12]:
  days=31
elif month in [4, 6, 9, 11]:
  days=30
else:
  if(year%400==0)or(year%4==0 and year%100!=0):
    days=29
  else:
    days=28

print(f'thang {month} nam {year} co {days} ngay.')
# Out:
# nhap thang: 8
# nhap nam: 2034
# thang 8 nam 2034 co 31 ngay.

# %%
# bai 4
n=int(input('nhap so tu nhien n co 4 chu so: '))
maxdigit=max(str(n))
print('chu so lon nhat cua', n, 'la: ', maxdigit)
# Out:
# nhap so tu nhien n co 4 chu so: 3857
# chu so lon nhat cua 3857 la:  8

# %%
# bai 5
a=float(input('diem toan:'))
b=float(input('diem ly: '))
c=float(input('diem hoa: '))
dtb=(a*2+b*3+c)/6
if 8<=dtb<=10:
  print('xep loai: gioi')
elif 6.5<=dtb<8:
  print('xep loai: kha')
elif 5<=dtb<6.5:
  print('xep loai: trung binh')
elif dtb<5:
  print('xep loai: yeu')
# Out:
# diem toan:8
# diem ly: 4
# diem hoa: 6
# xep loai: trung binh

# %%
# bai 6
chisocu=int(input('nhap chi so nuoc cu: '))
chisomoi=int(input('nhap chi so nuoc moi: '))
songuoi=int(input('nhap so nguoi trong ho: '))
tieuthu=chisomoi-chisocu
dinhmuc1=songuoi*4
dinhmuc2=songuoi*2
tiennuoc=0
if tieuthu<=dinhmuc1:
  tiennuoc=tieuthu*4400
elif tieuthu<=dinhmuc1+dinhmuc2:
  tiennuoc=dinhmuc1*4400+(tieuthu-dinhmuc1)*8300
else:
  tiennuoc=(dinhmuc1*4400+dinhmuc2*8300+(tieuthu-dinhmuc1-dinhmuc2)*10500)
tongtien=tiennuoc*1.15
print('so m3 tieu thu:', tieuthu)
print('tien nuoc phai tra:', tongtien, 'dong')
# Out:
# nhap chi so nuoc cu: 45
# nhap chi so nuoc moi: 78
# nhap so nguoi trong ho: 98
# so m3 tieu thu: 33
# tien nuoc phai tra: 166980.0 dong

# %%
# bai 7
import datetime

day = int(input('ngay: '))
month = int(input('thang: '))
year = int(input('nam: '))

today = datetime.date(year, month, day)
tomorrow = today + datetime.timedelta(days=1)

print("ngay tiep theo la:", tomorrow.strftime("%d/%m/%Y"))
# Out:
# ngay: 5
# thang: 2
# nam: 2042
# ngay tiep theo la: 06/02/2042

# %%
# bai 8
n=int(input('nhap n: '))
if n==0:
  sochuso=1
elif n<10:
  sochuso=1
elif n<100:
  sochuso=2
else:
  sochuso=3
tmp=n
tong=0
while tmp>0:
  tong+=tmp%10
  tmp//=10
chusocuoi=n%10
tmp=n
while tmp>=10:
  tmp//=10
chusodau=tmp
print('so chu so: ', sochuso)
print('tong cac chu so: ', tong)
print('chu so cuoi: ', chusocuoi)
# Out:
# nhap n: 395
# so chu so:  3
# tong cac chu so:  17
# chu so cuoi:  5
